# %%
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [raw]
# coding in java sucks

# %% [markdown]
# For those that don't understand, python rule java out!!!!!!

# %%
for i in range (10000):
    print("python rule")
# Out:
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# python rule
# ...
